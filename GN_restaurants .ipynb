# %%
# !pip install folium

# %%
import folium
map_osm = folium.Map(location=[28.4631779, 77.5107742])
map_osm.create_map(path='osm.html')

# %%
import folium

# Ghaziabad location coordinates
ghaziabad_location = [28.6692, 77.4538]

# Create a Folium map centered around Ghaziabad
map_osm = folium.Map(location=ghaziabad_location, zoom_start=12)

# Save the map to an HTML file
map_osm.create_map('ghaziabad_map.html')

# %%
import pandas as pd

# %%
G_noida = pd.read_csv("C:\\Users\\DELL\\Downloads\\HR botics\\Greater noida restaurants.csv")

# %%
G_noida
# Out:
#                                                   Name  Rating  \
# 0                                          Bikanervala     4.0
# 1           Rubaab Restaurant Jagat Farm Greater Noida     4.1
# 2                            Sagar Ratna Greater Noida     4.2
# 3                                    The Royal Kitchen     4.0
# 4                                    The Royal Kitchen     4.0
# ..                                                 ...     ...
# 115  Masala Resturants Unit of Corporate Club Hospi...     3.9
# 116  Perfecto Family Restaurant & Party Hall (Pure ...     4.5
# 117                                 Khatana restaurant     4.2
# 118                        Cross Avenue - Radisson Blu     4.2
# 119  Kifu Fnb Private Limited | Pure Korean Restaur...     5.0
#
#                                                   href  \
# 0    https://www.google.com/maps/place/Bikanervala/...
# 1    https://www.google.com/maps/place/Rubaab+Resta...
# ...

# %%
G_noida.isnull().sum()
# Out:
# Name           0
# Rating         1
# href           0
# attributes     0
# Latitude      16
# Longitude     16
# dtype: int64

# %%
G_noida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        120 non-null    object
#  1   Rating      119 non-null    float64
#  2   href        120 non-null    object
#  3   attributes  120 non-null    object
#  4   Latitude    104 non-null    float64
#  5   Longitude   104 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 5.8+ KB

# %%
G_noida.dropna(inplace=True)

# %%
G_noida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 0 to 118
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        104 non-null    object
#  1   Rating      104 non-null    float64
#  2   href        104 non-null    object
#  3   attributes  104 non-null    object
#  4   Latitude    104 non-null    float64
#  5   Longitude   104 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 5.7+ KB

# %%
G_noida.Latitude.value_counts()
# Out:
# 28.491523     2
# 28.482047     2
# 28.473033     2
# 28.451285     2
# 28.477579     2
#              ..
# 28.463141     1
# 28.487708     1
# 342.000000    1
# 28.487412     1
# 28.449815     1
# Name: Latitude, Length: 98, dtype: int64

# %%
#Checking greater than 29 latitude values and less than 27 latitude values 
G_noida[(G_noida["Latitude"] > 29) | (G_noida["Latitude"] < 27) ]
# Out:
#                                         Name  Rating  \
# 17                              Shahi Dawaat     4.0
# 37                            Nine to eleven     4.1
# 52                                Cooks Cafe     4.2
# 74                           Apna restaurant     5.0
# 76                           Barbeque Nation     4.4
# 77                              Atithi House     3.9
# 78                    Four Square Restaurant     4.4
# 84                Ram Rath South Indian Food     4.2
# 87   Orangery the casual dining - restaurant     4.8
# 89                                      SOUL     4.2
# 100                          BIRYANI N GRILL     3.9
# 117                       Khatana restaurant     4.2
#
#                                                   href  \
# 17   https://www.google.com/maps/place/Shahi+Dawaat...
# 37   https://www.google.com/maps/place/Nine+to+elev...
# 52   https://www.google.com/maps/place/Cooks+Cafe/d...
# ...

# %%
G_noidanew = G_noida[(G_noida["Latitude"] > 27) & (G_noida["Latitude"] < 29)]

# %%
G_noidanew
# Out:
#                                            Name  Rating  \
# 0                                   Bikanervala     4.0
# 1    Rubaab Restaurant Jagat Farm Greater Noida     4.1
# 2                     Sagar Ratna Greater Noida     4.2
# 3                             The Royal Kitchen     4.0
# 4                             The Royal Kitchen     4.0
# ..                                          ...     ...
# 111                            Kanha Restaurant     4.8
# 112                            Kanha Restaurant     4.8
# 113  The Dwelling Paradise - Hotel & Restaurant     4.6
# 114                              TRK Restaurant     2.5
# 118                 Cross Avenue - Radisson Blu     4.2
#
#                                                   href  \
# 0    https://www.google.com/maps/place/Bikanervala/...
# 1    https://www.google.com/maps/place/Rubaab+Resta...
# 2    https://www.google.com/maps/place/Sagar+Ratna+...
# 3    https://www.google.com/maps/place/The+Royal+Ki...
# ...

# %%
G_noidanew.to_csv("C:\\Users\\DELL\\Downloads\\cleaned_data.csv")

# %%
import folium
import pandas as pd

# Load the data from the CSV file
data_path = r'C:\Users\DELL\Downloads\HR botics\imp\cleaned_data.csv'
df = pd.read_csv(data_path)

# Create a Folium map centered around the average coordinates
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
map_osm = folium.Map(location=map_center, zoom_start=14)

# Add markers for each data point
for _, row in df.iterrows():
    popup_text = f"{row['Name']} (Rating: {row['Rating']})"
    folium.Marker(location=[row['Latitude'], row['Longitude']],
                  popup=popup_text).add_to(map_osm)

# Save the map to an HTML file
map_osm.save('restaurant_map.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32388\3371558380.py in <module>
#      13 for _, row in df.iterrows():
#      14     popup_text = f"{row['Name']} (Rating: {row['Rating']})"
# ---> 15     folium.Marker(location=[row['Latitude'], row['Longitude']],
#      16                   popup=popup_text).add_to(map_osm)
#      17
#
# AttributeError: module 'folium' has no attribute 'Marker'

# %%
pip install folium --upgrade
# Out:
# ...
#   Using cached folium-0.15.1-py2.py3-none-any.whl (97 kB)
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.1.5
#     Uninstalling folium-0.1.5:
#       Successfully uninstalled folium-0.1.5
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd

# Load the data from the CSV file
data_path = r'C:\Users\DELL\Downloads\GNrestaurants_cleaned .csv'
df = pd.read_csv(data_path)

# Create a Folium map centered around the average coordinates
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
map_osm = folium.Map(location=map_center, zoom_start=14, tiles='CartoDB positron')

# Add markers for each data point
for _, row in df.iterrows():
    # Add a star symbol in front of the ratings
    rating_with_star = f"★ {row['Rating']}"
    
    # HTML for the popup, including the image
    popup_html = f"""
    <div>
        <h4>Name: {row['Name']}</h4>
        <p style="font-size:16px;">Rating: {rating_with_star}</p>
        <img src="{row['attributes']}" alt="Restaurant Image" style="max-width:200px;">
    </div>
    """

    # Create a Popup with the HTML content
    popup = folium.Popup(html=popup_html, max_width=300)

    # Create the Marker with the Popup
    folium.Marker(location=[row['Latitude'], row['Longitude']],
                  popup=popup).add_to(map_osm)

# Save the map to an HTML file
map_osm.save('restaurant_map_with_images_and_stars.html')
